# %% [markdown]
# ## Imports Relevant Libraries

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# ## Import and Store Website links in variables

# %%
website = 'https://www.mbusa.com/en/all-vehicles?csref=mbcom_generic_pc#vbg-sedans-wagons'

# %% [markdown]
# ## Get Request

# %%
response = requests.get(website)

# %% [markdown]
# ## Status Code

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# ## Soup Object

# %%
soup = BeautifulSoup(response.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html data-country="us" data-language="en" dir="ltr" lang="en">
# <head>
# <title>All Vehicles | Mercedes-Benz USA</title>
# <meta content="View the entire line of Mercedes-Benz luxury sedans, coupes, SUVs, and sports cars organized by class and style. Discover our award-winning luxury vehicles." name="description"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta name="keywords"/>
# <meta content="unsafe-url" name="referrer"/>
# <meta content="mb-nafta.core-45.2.0-20220405043550-r50fff11aeb" name="site-version"/>
# <meta content="20220426:1101.43" name="exec-stamp"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
# <link href="/appletouchicon.png" rel="apple-touch-icon"/>
# <link href="https://www.mbusa.com/en/all-vehicles" rel="canonical"/>
# <link href="//assets.adobedtm.com" rel="preconnect"/>
# <link href="//mediaserver.mbusa.com" rel="preconnect"/>
# <link href="//www.google.com" rel="preconnect"/>
# <link href="//www.google-analytics.com" rel="preconnect"/>
# <link href="//stats.g.doubleclick.net" rel="preconnect"/>
# <link href="//googleads.g.doubleclick.net" rel="preconnect"/>
# <link href="//www.googleadservices.com" rel="preconnect"/>
# <link href="//nafta-service.mbusa.com" rel="preconnect"/>
# <link href="//ssl.google-analytics.com" rel="preconnect"/>
# <link href="//eai-paymentestimator-stage.ride.aws.mbusa.com" rel="preconnect"/>
# <link as="font" crossorigin="" href="https://nafta-service.mbusa.com/assets/now-ui-core/packages/foundation/0.63.5/assets/fonts/nafta-icons.woff" rel="preload" type="font/woff"/>
# <link as="font" crossorigin="" href="https://nafta-service.mbusa.com/assets/now-ui-core/packages/foundation/0.63.5/assets/fonts/MBCorpoATextCond-Regular-Web.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://nafta-service.mbusa.com/assets/now-ui-core/packages/foundation/0.63.5/assets/fonts/MBCorpoSText-Bold-Web.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://nafta-service.mbusa.com/assets/now-ui-core/packages/foundation/0.63.5/assets/fonts/MBCorpoSText-Regular-Web.woff2" rel="preload" type="font/woff2"/>
# <meta content="All Vehicles" property="og:title"/>
# <meta content="View the entire line of Mercedes-Benz luxury sedans, coupes, SUVs, and sports cars organized by class and style. Discover our award-winning luxury vehicles." property="og:description"/>
# <meta content="https://www.mbusa.com/content/dam/mb-nafta/us/footer/social-logo.jpg" property="og:image"/>
# <meta content="product" property="og:type"/>
# <link href="https://nafta-service.mbusa.com/assets/now-ui-core/packages/foundation/0.63.5/css/globals.css" rel="stylesheet"/>
# <link href="/etc/designs/mb-nafta/css/main.css" rel="stylesheet"/>
# <link href="/etc/designs/mb-nafta/css/vehicles-all.css" rel="stylesheet"/>
# <script async="" src="//assets.adobedtm.com/c9bd5a0b6c3b/59f06626cfbc/launch-5c38f5993ae8.min.js"></script>
# <script>
#     var mbNafta = window.mbNafta || {};
#     mbNafta.ns = function() {
#         var obj = window.mbNafta;
#         for (var x = 0, len = arguments.length; x < len; x++) {
#             var ns = arguments[x];
#             obj[ns] = obj[ns] || {};
#             obj = obj[ns];
#         }
#         return obj;
#     };
#
#     var mbDSDataLayer = window.mbDSDataLayer || {};
#     mbDSDataLayer.ns = function() {
#         var obj = window.mbDSDataLayer;
#         for (var x = 0, len = arguments.length; x < len; x++) {
#             var ns = arguments[x];
#             obj[ns] = obj[ns] || {};
#             obj = obj[ns];
#         }
#         return obj;
#     };
#
#     /*
#      * Public methods on the mbNafta namespace for loading dependency types.
#      * Please see documentation below for each method type
#      *
#      * @method loadScript
#      * Creates an collection of dependencies based on the type and adds
#      * the collection to the mbNafta[type] namespace
#      * @param type {String} Type of dependency to load
#      * @param names {String|Array} Name(s) of dependency to load
#      *
#      * eg:
#      * mbNafta.loadScript('apps', ['main', 'special-offers']);
#      * mbNafta.apps => ['main', 'special-offers']
#      *
#      * As a shortcut, each dependency type has its own method.
#      * loadApps([]) | loadExternalLibraries([]) | loadPlugins([])
#      * Each of these can independently be used and in any order.
#      */
#
#     /**
#      * @method mbNafta.loadScript
#      * @param type {String} Application type (apps, plugin)
#      * @param names {Array} Collection of dependency names
#      */
#     mbNafta.loadScript = function(type, names) {
#         mbNafta[type] = mbNafta[type] || [];
#
#         if(Array.isArray(names)) {
#             names.forEach(function(name) {
#                 if(mbNafta[type].indexOf(name) === -1) {
#                     mbNafta[type].push(name);
#                 }
#             });
#         } else if (typeof names === 'string' && !mbNafta.apps.includes(names)) {
#             mbNafta[type].push(names);
#         }
#     };
#
#     /**
#      * @method mbNafta.loadExternalLibraries
#      * @description Adds a list of external library dependency paths to the mbNafta.externalLibraries array
#      * @param externalLibrariesPaths {Array} Collection of external library paths
#      */
#     mbNafta.loadExternalLibraries = function(externalLibrariesPaths) {
#         mbNafta.loadScript('externalLibraries', externalLibrariesPaths);
#     };
#
#     /**
#      * @method mbNafta.loadApps
#      * @description Adds a list of app dependency names to the mbNafta.apps array
#      * @param appNames {Array} Collection of app names
#      */
#     mbNafta.loadApps = function(appNames) {
#         mbNafta.loadScript('apps', appNames);
#     };
#
#     /**
#      * @method mbNafta.loadPlugins
#      * @description Adds a list of plugin dependency names to the mbNafta.plugins array
#      * @param pluginNames {Array} Collection of plugin names
#      */
#     mbNafta.loadPlugins = function(pluginNames) {
#         mbNafta.loadScript('plugins', pluginNames);
#     };
# </script>
# </head>
# <body class="page all-vehicles">
# <div class="global-navigation-state" data-global-navigation-behavior="peek-a-boo">
# <header class="global-header" data-analytics-container="{ 'blade': 'header-top' }" data-load-module="GlobalHeader">
# <div class="top-bar">
# <div class="top-bar__inner">
# <a class="top-bar__skip-nav" data-analytics-trigger="cta-skip-nav" href="#content" tabindex="0">Skip Navigation</a>
# <a class="top-bar__logo" data-analytics-trigger="cta-logo" href="/en/home" title="Mercedes-Benz">
# <img alt="Mercedes-Benz" class="top-bar__logo-img" src="/etc/designs/mb-nafta/images/Mercedes_Benz__logo--desktop.png"/>
# </a>
# <button aria-label="back button" class="top-bar__back-button" data-analytics-trigger="cta-back">Back</button>
# <button aria-expanded="false" aria-label="main menu button" class="top-bar__hamburger-button" data-analytics-trigger="cta-hamburger">
# <svg class="top-bar__hamburger-button-line-wrapper top-bar__hamburger-button-line-wrapper--top" height="2px" version="1.1" width="23px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <line class="top-bar__hamburger-button-line top-bar__hamburger-button-line--top" stroke="#ffffff" stroke-width="3" x1="0" x2="23" y1="0" y2="0"></line>
# </svg>
# <svg class="top-bar__hamburger-button-line-wrapper top-bar__hamburger-button-line-wrapper--middle" height="2px" version="1.1" width="23px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <line class="top-bar__hamburger-button-line top-bar__hamburger-button-line--middle" stroke="#ffffff" stroke-width="3" x1="0" x2="23" y1="0" y2="0"></line>
# </svg>
# <svg class="top-bar__hamburger-button-line-wrapper top-bar__hamburger-button-line-wrapper--bottom" height="2px" version="1.1" width="23px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <line class="top-bar__hamburger-button-line top-bar__hamburger-button-line--bottom" stroke="#ffffff" stroke-width="3" x1="0" x2="23" y1="0" y2="0"></line>
# </svg>
# </button>
# </div>
# </div>
# <nav aria-expanded="false" aria-haspopup="true" aria-label="Menu" class="global-header__menu-l1 global-header__menu-l1--closed">
# <div class="global-header__hamburger-search-wrapper"></div>
# <div class="global-header__menu-l1__inner" data-analytics-container="{ 'blade': 'header-top' }">
# <ul aria-label="primary-menu" class="global-header__menu-l1-list" role="menu">
# <li class="global-header__menu-l1-list-item" role="none">
# <button aria-expanded="false" aria-haspopup="true" class="global-header__menu-l1-list-button" data-analytics-trigger="cta" role="menuitem">Vehicles</button>
# <div class="global-header__menu-l2">
# <ul aria-label="secondary-menu" class="global-header__menu-l2-list" data-analytics-container="{ 'blade': 'header-vehicles' }" role="menu">
# <li class="global-header__menu-l2-list-item" role="none">
# <button aria-expanded="false" aria-haspopup="true" class="global-header__menu-l2-list-button" data-analytics-trigger="cta" role="menuitem">SUVs</button>
# </li>
# <li class="global-header__menu-l2-list-item" role="none">
# <button aria-expanded="false" aria-haspopup="true" class="global-header__menu-l2-list-button" data-analytics-trigger="cta" role="menuitem">Sedans &amp; Wagons</button>
# </li>
# <li class="global-header__menu-l2-list-item" role="none">
# <button aria-expanded="false" aria-haspopup="true" class="global-header__menu-l2-list-button" data-analytics-trigger="cta" role="menuitem">Coupes</button>
# </li>
# <li class="global-header__menu-l2-list-item" role="none">
# <button aria-expanded="false" aria-haspopup="true" class="global-header__menu-l2-list-button" data-analytics-trigger="cta" role="menuitem">Convertibles &amp; Roadsters</button>
# </li>
# <li class="global-header__menu-l2-list-item" role="none">
# <button aria-expanded="false" aria-haspopup="true" class="global-header__menu-l2-list-button" data-analytics-trigger="cta" role="menuitem">Electric</button>
# </li>
# <li class="global-header__menu-l2-list-item" role="none">
# <button aria-expanded="false" aria-haspopup="true" class="global-header__menu-l2-list-button" data-analytics-trigger="cta" role="menuitem">Future &amp; Concept</button>
# </li>
# </ul>
# <div class="global-header__menu-l2-list">
# <ul aria-label="secondary-menu" class="primary-global-header__menu-l2-list" role="menubar">
# <li class="global-header__menu-l2-list-item" role="none">
# <a class="global-header__menu-l2-list-link" data-analytics-trigger="cta" href="/en/special-offers" role="menuitem">Special Offers</a>
# </li>
# <li class="global-header__menu-l2-list-item" role="none">
# <a class="global-header__menu-l2-list-link" data-analytics-trigger="cta" href="/en/compare-vehicles" role="menuitem">Compare Vehicles</a>
# </li>
# <li class="global-header__menu-l2-list-item" role="none">
# <a class="global-header__menu-l2-list-link" data-analytics-trigger="cta" href="/en/amg" role="menuitem">Mercedes-AMG</a>
# </li>
# <li class="global-header__menu-l2-list-item" role="none">
# <a class="global-header__menu-l2-list-link" data-analytics-trigger="cta" href="/en/cpo" role="menuitem">Certified Pre-Owned</a>
# </li>
# <li class="global-header__menu-l2-list-item" role="none">
# <a class="global-header__menu-l2-list-link" data-analytics-trigger="cta" href="/en/eq-electric-cars" role="menuitem">Mercedes-EQ</a>
# </li>
# <li class="global-header__menu-l2-list-item" role="none">
# <a class="global-header__menu-l2-list-link" data-analytics-trigger="cta" href="/en/all-vehicles" role="menuitem">All Vehicles</a>
# </li>
# </ul>
# <ul aria-label="secondary-menu" class="secondary-global-header__menu-l2-list" role="menubar">
# <li class="global-header__menu-l2-list-item" role="none">
# <a class="global-header__menu-l2-list-link global-header__saved-vehicles-link" data-analytics-trigger="cta-vehicle-global-nav" href="/en/account/saved-vehicles" role="menuitem">Saved Vehicles</a>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="global-header__menu-l1-list-item" role="none">
# <button aria-expanded="false" aria-haspopup="true" class="global-header__menu-l1-list-button" data-analytics-trigger="cta" role="menuitem">Shopping</button>
# <div class="global-header__menu-l2">
# <ul aria-label="secondary-menu" class="global-header__menu-l2-list" role="menubar">
# <li class="global-header__menu-l2-list-item" data-analytics-container="{ 'blade': 'header-shopping' }" role="none">
# <button aria-expanded="false" aria-haspopup="true" class="global-header__menu-l2-list-button" role="menuitem">Build &amp; Price</button>
# </li>
# <li class="global-header__menu-l2-list-item" data-analytics-container="{ 'blade': 'header-shopping' }" role="none">
# <button aria-expanded="false" aria-haspopup="true" class="global-header__menu-l2-list-button" role="menuitem">Owners</button>
# </li>
# <li class="global-header__menu-l2-list-item" data-analytics-container="{ 'blade': 'header-shopping' }" role="none">
# <button aria-expanded="false" aria-haspopup="true" class="global-header__menu-l2-list-button" role="menuitem">Finance</button>
# </li>
# <li class="global-header__menu-l2-list-item" data-analytics-container="{ 'blade': 'header-shopping' }" role="none">
# <button aria-expanded="false" aria-haspopup="true" class="global-header__menu-l2-list-button" role="menuitem">Accessories</button>
# </li>
# <li class="global-header__menu-l2-list-item global-header__menu-l2-list-item--button" data-analytics-container="{ 'blade': 'header-shopping' }" role="none">
# <button aria-expanded="false" aria-haspopup="true" class="global-header__menu-l2-list-button" role="menuitem">Special Offers</button>
# </li>
# <li class="global-header__menu-l2-list-item global-header__menu-l2-list-item--tile" data-analytics-container="{ 'blade': 'header-shopping' }" role="none">
# <div class="nav-link-group nav-link-group--secondary">
# <div class="nav-link-group__image-wrapper">
# <picture data-load-module="LazyLoader">
# <img alt="" class="nav-link-group__image" data-lazy-src="/content/dam/mb-nafta/us/global-header/shopping/OW-GLOBALNAV-SHOPPING-INVENTORY-S+XL@1.5x.jpg" role="presentation" src="/etc/designs/mb-nafta/images/blank.gif"/>
# </picture>
# </div>
# <p class="nav-link-group__heading">Special Offers</p>
# <ul class="nav-link-group__links" role="menu">
# <li class="nav-link-group__link">
# <a class="link link_in-text" data-analytics-trigger="cta" href="/en/special-offers" role="menuitem">New Vehicle Offers</a>
# </li>
# <li class="nav-link-group__link">
# <a class="link link_in-text" data-analytics-trigger="cta" href="/en/special-offers#certified-pre-owned" role="menuitem">Certified Pre-Owned Offers</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="global-header__menu-l2-list-item global-header__menu-l2-list-item--button" data-analytics-container="{ 'blade': 'header-owners-subnav-module' }" role="none">
# <button aria-expanded="false" aria-haspopup="true" class="global-header__menu-l2-list-button global-header__menu-l2-list-button--unauthenticated" data-analytics-trigger="account-open" role="menuitem">Log In or Register</button>
# <button aria-expanded="false" aria-haspopup="true" class="global-header__menu-l2-list-button global-header__menu-l2-list-button--authenticated" data-analytics-trigger="account-open" role="menuitem">My Mercedes me ID</button>
# </li>
# <li class="global-header__menu-l2-list-item global-header__menu-l2-list-item--tile" data-analytics-container="{ 'blade': 'header-owners-subnav-module' }" role="none">
# <section class="nav-profile" data-analytics-container="{ 'blade': 'header-owners-subnav-module' }" data-analytics-trigger="account-open" data-load-module="NavProfileModule">
# <div class="nav-profile__container nav-profile__container--unauthenticated">
# <p class="nav-profile__heading" tabindex="0">
#                             Log In or Register
#                         </p>
# <p class="nav-profile__description" tabindex="0">
#                             Even if you don’t own a Mercedes-Benz, you can register for an account to save builds, track inventory, set alerts and more.
#                         </p>
# <div class="nav-profile__buttons-wrapper">
# <div class="nav-profile__button-container">
# <button class="nav-profile__login nav-profile__button button button_primary button--wide" data-analytics-trigger="account-login">Log In</button>
# </div>
# <div class="nav-profile__button-container">
# <button class="nav-profile__register nav-profile__link" data-analytics-trigger="account-register">Register</button>
# </div>
# </div>
# </div>
# <div class="nav-profile__container nav-profile__container--authenticated">
# <p class="nav-profile__heading" tabindex="0">
#                             My Mercedes me ID
#                         </p>
# <div class="nav-profile__links-list">
# <a class="nav-profile__link" data-analytics-trigger="cta" href="/en/account/saved-vehicles">Saved Vehicles</a>
# <a class="nav-profile__link" data-analytics-trigger="cta" href="/en/account/vehicle-deals">Deals In Progress</a>
# </div>
# <div class="nav-profile__buttons-wrapper">
# <div class="nav-profile__button-container">
# <a class="nav-profile__button button button_primary button--wide" data-analytics-trigger="cta-view-profile" href="/en/account">View Account</a>
# </div>
# <div class="nav-profile__button-container">
# <button class="nav-profile__logout nav-profile__link" data-analytics-trigger="cta-log-out" rel="noopener">Log Out</button>
# </div>
# </div>
# </div>
# </section>
# </li>
# </ul>
# </div>
# </li>
# <li class="global-header__menu-l1-list-item" role="none">
# <button aria-expanded="false" aria-haspopup="true" class="global-header__menu-l1-list-button" data-analytics-trigger="cta" role="menuitem">Inventory</button>
# <div class="global-header__menu-l2 global-header__menu-l2--additional">
# <ul aria-label="secondary-menu" class="global-header__menu-l2-list" role="menubar">
# <li class="global-header__menu-l2-list-item" data-analytics-container="{ 'blade': 'header-additional' }" role="none">
# <button aria-expanded="false" aria-haspopup="true" class="global-header__menu-l2-list-button" role="menuitem">New Vehicles</button>
# </li>
# <li class="global-header__menu-l2-list-item" data-analytics-container="{ 'blade': 'header-additional' }" role="none">
# <button aria-expanded="false" aria-haspopup="true" class="global-header__menu-l2-list-button" role="menuitem">Certified Pre‑Owned</button>
# </li>
# <li class="global-header__menu-l2-list-item global-header__menu-l2-list-item--button" data-analytics-container="{ 'blade': 'header-additional' }" role="none">
# <button aria-expanded="false" aria-haspopup="true" class="global-header__menu-l2-list-button" role="menuitem">Save Time and Shop Online</button>
# <button aria-expanded="false" aria-haspopup="true" class="global-header__menu-l2-list-button global-header__menu-l2-list-button--hidden" role="menuitem">RECENTLY VIEWED</button>
# </li>
# <li class="global-header__menu-l2-list-item global-header__menu-l2-list-item--tile" data-analytics-container="{ 'blade': 'header-additional' }" role="none">
# <section class="nav-promo-tile">
# <div class="nav-promo-tile__image-wrapper">
# <picture data-load-module="LazyLoader">
# <img alt="" class="nav-promo-tile__image" data-lazy-src="/content/dam/mb-nafta/us/global-header/images-global-nav-shop-online.jpg" role="presentation" src="/etc/designs/mb-nafta/images/blank.gif"/>
# </picture>
# </div>
# <p class="nav-promo-tile__heading" tabindex="0">Save Time and Shop Online</p>
# <p class="nav-promo-tile__subhead" tabindex="0">
#                         Shop select Certified Pre-Owned vehicles, and build your deal online in a few easy steps.
#
#
#
#
#                     </p>
# <div class="nav-promo-tile__buttons-wrapper">
# <div class="nav-promo-tile__button-container">
# <a class="nav-promo-tile__button button button_primary button--wide" data-analytics-trigger="cta-primary" href="/en/reservations">How It Works</a>
# </div>
# <div class="nav-promo-tile__button-container">
# <a class="nav-promo-tile__link" data-analytics-trigger="cta-secondary" href="/en/cpo/inventory?includeReserveOnly=true">Build Your Deal</a>
# </div>
# </div>
# </section>
# </li>
# </ul>
# </div>
# <!--Include dealerForm localization-->
# <script>
#     mbNafta.ns('applicationProperties').dealerForm = {
#         leadsEndpoint: '/content/public-api/forms/leads',
#         providers: {},
#         ...mbNafta.ns('applicationProperties', 'dealerForm')
#     };
#     mbNafta.ns('moduleData', 'recentlyViewedVehicle').config = {
#         enableCommerce: "true" === "true",
#         showRecentlyViewedVehicle: "RECENTLY VIEWED" !== '',
#         recentlyViewedVehicleMenuHeader: "RECENTLY VIEWED",
#     };
#
#     mbNafta.ns('moduleData', 'recentlyViewedVehicle').endpoints = {
#         contactDealerURI: "/en/contact-us/contact-a-dealer",
#         cpoVdpUrl: "/en/cpo/inventory/vehicle/{dealerName}/{dealerId}/{classId}/{bodyStyleId}/{modelId}/{vin}",
#         monolithImagePatterns: {
#             AMG: "/content/dam/mb-nafta/us/preferences/inventory-preferences/Monolith-background-AMG.png",
#             DEFAULT: "/content/dam/mb-nafta/us/preferences/inventory-preferences/Monolith-background.png"
#         },
#         suvFallbackImagePattern: "/content/dam/mb-nafta/us/inventory/thumbnail-not-available-silhouette-suv.png",
#         vehicleDetailsEndpoint: '/content/public-api/vd/active-model',
#         vehicleFallbackImagePattern: "/content/dam/mb-nafta/us/inventory/thumbnail-not-available-silhouette-sedan.png",
#         vdpUrl: "/en/inventory/{dealerName}/{dealerId}/{classId}/{bodyStyleId}/{modelId}/{vin}",
#         vehicleLookup: '/vehicles/lookup/vin'
#     };
#
#     mbNafta.ns('moduleData', 'recentlyViewedVehicle').localization = {
#         availabilityToolTip: "Availability can change daily. Please contact the dealer to confirm actual availability.",
#         contactDealer: "Contact Dealer",
#         cpoInventory: JSON.parse('{\x22config\x22:{\x22pageDisclaimers\x22:[{\x22autoNum\x22:false,\x22error\x22:false,\x22legend\x22:\x22*\x22,\x22disclaimerKey\x22:\x22Global MSRP\x22,\x22disclaimerText\x22:\x22<p>Base MSRP excludes transportation and handling charges, destination charges, taxes, title, registration, preparation and documentary fees, tags, labor and installation charges, insurance, and optional equipment, products, packages and accessories. Actual vehicle price may vary by Dealer. <\/p>\\r\\n<p>MBFS NMLS #2546<\/p>\\r\\n\x22,\x22categoryKey\x22:\x22GLOBAL\x22,\x22custom\x22:false},{\x22autoNum\x22:false,\x22error\x22:false,\x22legend\x22:\x22**\x22,\x22disclaimerKey\x22:\x22Acceleration\x22,\x22disclaimerText\x22:\x22<p>Stated rates of acceleration are based upon manufacturer\x27s track results and may vary depending on model, environmental and road surface conditions, driving style, elevation and vehicle load.<\/p>\\r\\n\x22,\x22categoryKey\x22:\x22GLOBAL\x22,\x22custom\x22:false},{\x22autoNum\x22:false,\x22error\x22:false,\x22legend\x22:\x22†\x22,\x22disclaimerKey\x22:\x22MPG\x22,\x22disclaimerText\x22:\x22<p>EPA estimated fuel economy. Compare the estimated mpg to the estimated mpg of other vehicles. You may get different mileage depending on how fast you drive, weather conditions and trip length. Your actual highway mileage will probably be less than the highway estimate.<\/p>\\r\\n\x22,\x22categoryKey\x22:\x22GLOBAL\x22,\x22custom\x22:false},{\x22autoNum\x22:false,\x22error\x22:false,\x22legend\x22:\x22‡\x22,\x22disclaimerKey\x22:\x22Towing\x22,\x22disclaimerText\x22:\x22<p>With optional trailer hitch. Read Operator’s Manual before towing. In some states, aftermarket trailer brakes are required. See dealer for details.<\/p>\\r\\n\x22,\x22categoryKey\x22:\x22GLOBAL\x22,\x22custom\x22:false},{\x22autoNum\x22:true,\x22error\x22:false,\x22legend\x22:\x221\x22,\x22disclaimerKey\x22:\x22global\u002Dfuture\u002Dconcept\u002Dvehicles\x22,\x22disclaimerText\x22:\x22<p>Vehicle may not be exactly as shown.<\/p>\\r\\n\x22,\x22categoryKey\x22:\x22GLOBAL\x22,\x22custom\x22:false},{\x22autoNum\x22:true,\x22error\x22:false,\x22legend\x22:\x222\x22,\x22disclaimerKey\x22:\x22global\u002Dconcept\u002Dcar\x22,\x22disclaimerText\x22:\x22<p>As a concept car, the designs, features, etc. are subject to change.<\/p>\\r\\n\x22,\x22categoryKey\x22:\x22GLOBAL\x22,\x22custom\x22:false}]},\x22content\x22:{\x22acceleration\x22:\x22Acceleration\x22,\x22additionalResultsHeading\x22:\x22Additional Search Results\x22,\x22askCustomOrder\x22:\x22Want to ask about a custom order?\x22,\x22automaticTransmission\x22:\x22Automatic Transmission\x22,\x22availableNow\x22:\x22Available Now\x22,\x22availableNowAt\x22:\x22Available now at:\x22,\x22availableUponRequest\x22:\x22Available Upon Request\x22,\x22availableUponRequestAt\x22:\x22Available Upon Request at:\x22,\x22backCta\x22:\x22Back to Results\x22,\x22badges\x22:{\x22all\x22:\x22All Locations\x22,\x22amg\x22:\x22AMG Performance Center\x22,\x22amgelite\x22:\x22AMG Performance Center Elite\x22,\x22ccdropoffonly\x22:\x22Collision Center Drop\u002Doff Only\x22,\x22cpo\x22:\x22Certified Pre\u002DOwned\x22,\x22collisioncenter\x22:\x22Collision Center\x22,\x22elitecollisioncenter\x22:\x22Elite Collision Center (Aluminum Welding)\x22,\x22mobileservice\x22:\x22Mobile Service by Mercedes\u002DBenz\x22,\x22maybach\x22:\x22Maybach Dealership\x22,\x22mbdealer\x22:\x22Dealership\x22,\x22partspro\x22:\x22Parts Pro Dealership\x22,\x22prmrexp\x22:\x22Express Service by MB\x22,\x22sales\x22:\x22Sales\x22,\x22service\x22:\x22Service and Parts\x22,\x22zevst\x22:\x22Zero Emission Vehicle State\x22},\x22body\x22:\x22Body\x22,\x22bodyStyle\x22:\x22Body Style\x22,\x22cargoCapacity\x22:\x22Cargo capacity\x22,\x22certifiedPreOwned\x22:\x22Certified Pre\u002DOwned\x22,\x22change\x22:\x22Change\x22,\x22cityFuelEconomy\x22:\x22City fuel economy\x22,\x22closeDisclaimer\x22:\x22Close Disclaimer\x22,\x22comfort\x22:\x22Com ...
#         dealerPrice: "Dealer Price",
#         heading: "Recently Viewed",
#         isAvailable: "Available Now",
#         isNotAvailable: "Available Upon Request",
#         inventory: {
#             ...window.mbNafta.ns('pageData', 'localization', 'inventory'),
#             disclaimerTotalOnlinePrice: "{\x22autoNum\x22:false,\x22error\x22:false,\x22disclaimerKey\x22:\x22COMM\u002DONLINEPRICE\x22,\x22disclaimerText\x22:\x22<p>The actual purchase price of the vehicle is subject to change by the dealer and may vary based on location of the Dealer and customer, inventory levels, vehicle features and available discounts and rebates. The Online Price excludes taxes and\/or fees resulting from the sale of the vehicle, including, but not limited to destination charges, labor, title, license\x26nbsp;and installation charges.<\/p>\\r\\n\x22,\x22categoryKey\x22:\x22commerce\x22,\x22categoryText\x22:\x22commerce\x22,\x22disclaimerJcrPath\x22:\x22\/content\/mb\u002Dnafta\/en_us\/admin\/disclaimers\/commerce\/jcr:content\/content\u002Dcontainer\/disclaimer_text_1154983451\x22,\x22categoryJcrPath\x22:\x22\/content\/mb\u002Dnafta\/en_us\/admin\/disclaimers\/commerce\/jcr:content\/disclaimer\u002Dcategory\x22,\x22custom\x22:false}" ? JSON.parse("{\x22autoNum\x22:false,\x22error\x22:false,\x22disclaimerKey\x22:\x22COMM\u002DONLINEPRICE\x22,\x22disclaimerText\x22:\x22<p>The actual purchase price of the vehicle is subject to change by the dealer and may vary based on location of the Dealer and customer, inventory levels, vehicle features and available discounts and rebates. The Online Price excludes taxes and\/or fees resulting from the sale of the vehicle, including, but not limited to destination charges, labor, title, license\x26nbsp;and installation charges.<\/p>\\r\\n\x22,\x22categoryKey\x22:\x22commerce\x22,\x22categoryText\x22:\x22commerce\x22,\x22disclaimerJcrPath\x22:\x22\/content\/mb\u002Dnafta\/en_us\/admin\/disclaimers\/commerce\/jcr:content\/content\u002Dcontainer\/disclaimer_text_1154983451\x22,\x22categoryJcrPath\x22:\x22\/content\/mb\u002Dnafta\/en_us\/admin\/disclaimers\/commerce\/jcr:content\/disclaimer\u002Dcategory\x22,\x22custom\x22:false}") : {},
#         },
#         msrp: "MSRP",
#         onlinePrice: "Online Price",
#         priceComingSoon: "Price Coming Soon",
#         reserveCta: "Build Your Deal",
#         stillAvailable: "Still Available",
#         unlockEPrice: "Unlock E\u002DPrice",
#         viewVehicleDetails: "View Vehicle Details",
#     };
# </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["REQUEST_QUOTE"] = {
#             providerId: "275",
#             providerName: "mbusa.com \u002D Request Quote"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["NEW_INVT_GET_E_PRICE"] = {
#             providerId: "273",
#             providerName: "mbusa.com \u002D Inventory \u002D New Inventory \u002D Get E\u002DPrice"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["PROFILE_CPO_INVT_GET_E_PRICE"] = {
#             providerId: "390",
#             providerName: "mbusa.com – Saved Vehicles \u002D CPO \u002D Get E\u002DPrice"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["PE_REQUEST_QUOTE"] = {
#             providerId: "329",
#             providerName: "mbusa.com \u002D Payment Estimator \u002D Request Quote"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["PROFILE_CPO_CONTACT_DEALER"] = {
#             providerId: "320",
#             providerName: "mbusa.com \u002D Profile \u002D Inventory Favorites \u002D Contact Dealer \u002D CPO Inventory"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["PROFILE_PRICE_SOON_IM_INTERESTED"] = {
#             providerId: "372",
#             providerName: "mbusa.com \u002D Profile \u002D Saved Build \u002D Im Interested \u002D Price Coming Soon"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["CPO_INVT_IM_INTERESTED"] = {
#             providerId: "340",
#             providerName: "mbusa.com \u002D Inventory \u002D DSE – CPO – Interested customer"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["CPO_RESERVE"] = {
#             providerId: "264",
#             providerName: "mbusa.com \u002D DSE \u002D CPO \u002D Reserve"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["NEW_INVT_IM_INTERESTED"] = {
#             providerId: "416",
#             providerName: "mbusa.com \u002D DRS \u002D New \u002D Interested Customer"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["BYO_SCH_TEST_DRIVE"] = {
#             providerId: "268",
#             providerName: "mbusa.com \u002D Build your own \u002D Schedule Test Drive"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["CPO_INVT_HOME_SCH_TEST_DRIVE"] = {
#             providerId: "266",
#             providerName: "mbusa.com \u002D Inventory \u002D CPO \u002D Schedule Test Drive \u002D Home Test Drive Request"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["PROFILE_NEW_INVT_GET_E_PRICE"] = {
#             providerId: "391",
#             providerName: "mbusa.com – Saved Vehicles \u002D New Inventory \u002D Get E\u002DPrice"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["CPO_INVT_NON_DSE_IM_INTERESTED"] = {
#             providerId: "449",
#             providerName: "mbusa.com \u002D Inventory \u002D Non\u002DDSE – CPO – Interested customer"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["MKTP_WARRANTY_MAINTENANCE"] = {
#             providerId: "389",
#             providerName: "mbusa.com \u002D Marketplace \u002D PPM\/ELW Packages"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["MODEL_REQUEST_QUOTE"] = {
#             providerId: "277",
#             providerName: "mbusa.com \u002D Model Page \u002D Request Quote"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["SO_CONTACT_DEALER"] = {
#             providerId: "279",
#             providerName: "mbusa.com \u002D Special Offers \u002D Contact Dealer"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["PO_RESERVE"] = {
#             providerId: "367",
#             providerName: "mbusa.com \u002D DSE \u002D Pre\u002DOwned \u002D Completed deal"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["NEW_INVT_SCH_TEST_DRIVE"] = {
#             providerId: "274",
#             providerName: "mbusa.com \u002D Inventory \u002D New Inventory \u002D Schedule Test Drive"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["CPO_RESERVE_CONTACT_DEALER"] = {
#             providerId: "360",
#             providerName: "mbusa.com \u002D DSE \u002D CPO \u002D Contact Dealer"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["MODEL_SCH_TEST_DRIVE"] = {
#             providerId: "278",
#             providerName: "mbusa.com \u002D Model Page \u002D Schedule Test Drive"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["FLEET_PROGRAM_CONTACT_DEALER"] = {
#             providerId: "322",
#             providerName: "mbusa.com \u002D Fleet Program \u002D B2B \u002D Contact Dealer"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["NEW_INVT_CONTACT_DEALER"] = {
#             providerId: "272",
#             providerName: "mbusa.com \u002D Inventory \u002D New Inventory \u002D Contact Dealer"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["BYO_REQUEST_QUOTE"] = {
#             providerId: "267",
#             providerName: "mbusa.com \u002D Build your own \u002D Request Quote"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["PO_INVT_GET_E_PRICE"] = {
#             providerId: "336",
#             providerName: "mbusa.com \u002D Inventory \u002D Pre\u002DOwned \u002D Get E\u002DPrice"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["PO_RESERVE_SCH_TEST_DRIVE"] = {
#             providerId: "370",
#             providerName: "mbusa.com \u002D DSE \u002D Pre\u002DOwned \u002D Test drive request"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["PROFILE_CREDIT_CONTACT_DEALER"] = {
#             providerId: "321",
#             providerName: "mbusa.com \u002D Profile \u002D Credit App \u002D Contact Dealer"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["CPO_INVT_GET_E_PRICE"] = {
#             providerId: "270",
#             providerName: "mbusa.com \u002D Inventory \u002D CPO \u002D Get E\u002DPrice"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["NEW_CAR_RESERVE"] = {
#             providerId: "407",
#             providerName: "mbusa.com \u002D DSE \u002D New \u002D Completed deal"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["PO_INVT_IM_INTERESTED"] = {
#             providerId: "368",
#             providerName: "mbusa.com \u002D Inventory \u002D DSE \u002D Pre\u002DOwned \u002D Interested Customer"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["HOME_DELIVERY_CPO_RESERVE"] = {
#             providerId: "265",
#             providerName: "mbusa.com \u002D DSE \u002D CPO \u002D Reserve \u002D Home Delivery Request"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["NEW_RESERVE_CONTACT_DEALER"] = {
#             providerId: "409",
#             providerName: "mbusa.com \u002D DSE \u002D New \u002D Dealer contact request"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["PO_INVT_NON_DSE_IM_INTERESTED"] = {
#             providerId: "448",
#             providerName: "mbusa.com \u002D Inventory \u002D Non\u002DDSE \u002D Pre\u002DOwned \u002D Interested Customer"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["CPO_RESERVE_SCH_TEST_DRIVE"] = {
#             providerId: "361",
#             providerName: "mbusa.com \u002D DSE \u002D CPO \u002D Schedule a Test Drive"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["PO_RESERVE_CONTACT_DEALER"] = {
#             providerId: "369",
#             providerName: "mbusa.com \u002D DSE \u002D Pre\u002DOwned \u002D Dealer contact request"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["CPO_CONTACT_DEALER"] = {
#             providerId: "269",
#             providerName: "mbusa.com \u002D CPO Special Offers \u002D Contact Dealer"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["PO_INVT_SCH_TEST_DRIVE"] = {
#             providerId: "337",
#             providerName: "mbusa.com \u002D Inventory \u002D Pre\u002DOwned \u002D Schedule Test Drive"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["CONTACT_DEALER"] = {
#             providerId: "275",
#             providerName: "mbusa.com \u002D Request Quote"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["CPO_INVT_SCH_TEST_DRIVE"] = {
#             providerId: "271",
#             providerName: "mbusa.com \u002D Inventory \u002D CPO \u002D Schedule Test Drive"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["FLEET_PEP"] = {
#             providerId: "392",
#             providerName: "mbusa.com \u002D Fleet Program \u002D PEP \u002D Contact Dealer"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["PROFILE_NEW_CONTACT_DEALER"] = {
#             providerId: "319",
#             providerName: "mbusa.com \u002D Profile \u002D Inventory Favorites \u002D Contact Dealer \u002D New Inventory"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["SCH_TEST_DRIVE"] = {
#             providerId: "276",
#             providerName: "mbusa.com \u002D Schedule Test Drive"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["EUROPEAN_DELIVERY_CONTACT_DEALER"] = {
#             providerId: "323",
#             providerName: "mbusa.com \u002D European Delivery \u002D Contact Dealer"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["BYO_CONTACT_DEALER_IM_INTERESTED"] = {
#             providerId: "371",
#             providerName: "mbusa.com \u002D Build Your Own \u002D Im Interested \u002D Price Coming Soon"
#         };
#     </script>
# <script>
#         mbNafta.ns('applicationProperties', 'dealerForm', 'providers')["NEW_RESERVE_SCH_TEST_DRIVE"] = {
#             providerId: "410",
#             providerName: "mbusa.com \u002D DSE \u002D New \u002D Test drive request"
#         };
#     </script>
# </li>
# </ul>
# <ul aria-label="secondary-menu" class="global-header__menu-l1-list global-header__menu-l1-list--secondary" role="menubar">
# <li class="global-header__menu-l1-list-item" role="none">
# <button aria-expanded="false" aria-haspopup="true" class="global-header__menu-l1-list-button global-header__menu-l1-list-button--icon-pin" data-analytics-trigger="cta" data-default-open-menu="true" role="menuitem">Find a Dealer</button>
# <div class="global-header__menu-l2 global-header__menu-l2--dealer">
# <div aria-label="secondary-menu" class="global-header__menu-l2-list" data-analytics-container="{ 'blade': 'dealer-selector' }">
# <script>
#     mbNafta.ns('pageData', 'globalHeader').dealerMenu = {
#         localization: {
#             searchCTA: "Search",
#             searchInputLabel: "Enter ZIP Code or City, State",
#             dealerSearchErrorMessage: "Invalid ZIP Code or City, State"
#         },
#         config: {
#             dealerSearchUrl: "/en/dealers"
#         }
#     };
# </script>
# <section class="global-header__location-input">
# <div class="global-header__location-input__search-bar__container"></div>
# </section>
# </div>
# </div>
# </li>
# <li class="global-header__menu-l1-list-item" role="none">
# <button aria-expanded="false" aria-haspopup="true" class="global-header__menu-l1-list-button global-header__menu-l1-list-button--icon-profile global-header__menu-l1-list-button-utility" data-analytics-trigger="cta" role="menuitem">
# <span class="global-header__menu-l1-list-button-utility-inner">My Account</span>
# </button>
# <div class="global-header__menu-l2">
# <ul aria-label="secondary-menu" class="global-header__menu-l2-list" data-analytics-container="{ 'blade': 'header-utility' }" role="menubar">
# <li class="global-header__menu-l2-list-item" role="none">
# <button aria-expanded="false" aria-haspopup="true" class="global-header__menu-l2-list-button" role="menuitem"><i>Mercedes me</i></button>
# </li>
# <li class="global-header__menu-l2-list-item" role="none">
# <button aria-expanded="false" aria-haspopup="true" class="global-header__menu-l2-list-button nav-profile__l2-button--unauthenticated" role="menuitem">Log In or Register</button>
# <button aria-expanded="false" aria-haspopup="true" class="global-header__menu-l2-list-button nav-profile__l2-button--authenticated" role="menuitem">My Mercedes me ID</button>
# </li>
# </ul>
# </div>
# </li>
# <li class="global-header__menu-l1-list-item global-header__menu-l1-list-item--search" role="none">
# <button aria-expanded="false" aria-haspopup="true" class="global-header__menu-l1-list-button global-header__menu-l1-list-button--search icon-mb icon-search" data-analytics-trigger="search" role="menuitem">
# <span class="offscreen">Search</span>
# </button>
# </li>
# </ul>
# </div>
# <ul class="global-header__menu-l3">
# <li class="global-header__menu-l3-content global-header__menu-l3-content--vehicles">
# <div class="global-header__menu-l3__container-background">
# <div class="global-header__menu-l3__container-spacing">
# <p class="global-header__menu-l3-headline">Vehicles</p>
# <div class="global-header__menu-l3-tabs-container">
# <ul aria-label="body styles" class="global-header__menu-l3-tabs" data-analytics-container="{ 'blade': 'header-vehicles' }" role="tablist">
# <li class="global-header__menu-l3-tab" role="none">
# <button aria-selected="false" class="global-header__menu-l3-tab-button" data-analytics-trigger="cta" role="tab">SUVs</button>
# </li>
# <li class="global-header__menu-l3-tab" role="none">
# <button aria-selected="false" class="global-header__menu-l3-tab-button" data-analytics-trigger="cta" role="tab">Sedans &amp; Wagons</button>
# </li>
# <li class="global-header__menu-l3-tab" role="none">
# <button aria-selected="false" class="global-header__menu-l3-tab-button" data-analytics-trigger="cta" role="tab">Coupes</button>
# </li>
# <li class="global-header__menu-l3-tab" role="none">
# <button aria-selected="false" class="global-header__menu-l3-tab-button" data-analytics-trigger="cta" role="tab">Convertibles &amp; Roadsters</button>
# </li>
# <li class="global-header__menu-l3-tab" role="none">
# <button aria-selected="false" class="global-header__menu-l3-tab-button" data-analytics-trigger="cta" role="tab">Electric</button>
# </li>
# <li class="global-header__menu-l3-tab" role="none">
# <button aria-selected="false" class="global-header__menu-l3-tab-button" data-analytics-trigger="cta" role="tab">Future &amp; Concept</button>
# </li>
# </ul>
# </div>
# <div class="global-header__vehicles-link-list">
# <ul aria-label="secondary-menu" class="primary-global-header__vehicles-link-list" role="menubar">
# <li class="global-header__vehicles-link-list-item" role="none">
# <a class="global-header__vehicles-link-list-item-link" data-analytics-trigger="cta" href="/en/special-offers" role="menuitem">Special Offers</a>
# </li>
# <li class="global-header__vehicles-link-list-item" role="none">
# <a class="global-header__vehicles-link-list-item-link" data-analytics-trigger="cta" href="/en/compare-vehicles" role="menuitem">Compare Vehicles</a>
# </li>
# <li class="global-header__vehicles-link-list-item" role="none">
# <a class="global-header__vehicles-link-list-item-link" data-analytics-trigger="cta" href="/en/amg" role="menuitem">Mercedes-AMG</a>
# </li>
# <li class="global-header__vehicles-link-list-item" role="none">
# <a class="global-header__vehicles-link-list-item-link" data-analytics-trigger="cta" href="/en/cpo" role="menuitem">Certified Pre-Owned</a>
# </li>
# <li class="global-header__vehicles-link-list-item" role="none">
# <a class="global-header__vehicles-link-list-item-link" data-analytics-trigger="cta" href="/en/eq-electric-cars" role="menuitem">Mercedes-EQ</a>
# </li>
# <li class="global-header__vehicles-link-list-item" role="none">
# <a class="global-header__vehicles-link-list-item-link" data-analytics-trigger="cta" href="/en/all-vehicles" role="menuitem">All Vehicles</a>
# </li>
# </ul>
# <ul aria-label="secondary-menu" class="secondary-global-header__vehicles-link-list" role="menubar">
# <li class="global-header__vehicles-link-list-item" role="none">
# <a class="global-header__vehicles-link-list-item-link global-header__saved-vehicles-link" data-analytics-trigger="cta-vehicle-global-nav" href="/en/account/saved-vehicles" role="menuitem">Saved Vehicles</a>
# </li>
# </ul>
# </div>
# <div class="global-header__menu-l3-panel-wrapper">
# <ul class="global-header__menu-l3-panel-list">
# <li class="global-header__menu-l3-panel-item" role="tabpanel">
# <ul class="global-header__grid">
# <li class="global-header__item">
# <div class="global-header__item-tile">
# <a class="global-header__item-link" data-analytics-trigger="cta" href="/en/vehicles/class/gla/suv">
# <picture class="global-header__item-vehicle-picture responsive-image" data-load-module="LazyLoader">
# <img alt="" class="global-header__item-vehicle-image" data-lazy-src="/content/dam/mb-nafta/us/global-header/vehicles/OW-GLOBALNAV-VEHICLEDROPDOWN-SUV-GLA@1.5x.jpg" role="presentation" src="/etc/designs/mb-nafta/images/blank.gif"/>
# </picture>
# <p class="global-header__item-vehicle-name">GLA SUV</p>
# <p class="global-header__item-vehicle-msrp" tabindex="0">
# <span>Starting at</span>
# <span>$36,400</span>
# <span class="disclaimer">*</span>
# </p>
# </a>
# <button aria-controls="global-header__item-models-cta-0-0" aria-expanded="false" aria-haspopup="true" class="global-header__item-models-cta toggle-drawer-cta--global-nav" data-analytics-trigger="cta" data-toggle-drawer-button="">
#                                         Models
#                                     </button>
# <div aria-hidden="true" class="toggle-drawer toggle-drawer--global-nav" data-toggle-drawer-index="0" id="global-header__item-models-cta-0-0">
# <ul class="global-header__item-models-list" role="menu" tabindex="-1">
# <li class="global-header__item-models-list-item" role="none">
# <a class="global-header__item-models-list-item-cta--model link" data-analytics-trigger="cta" href="/en/vehicles/model/gla/suv/gla250w" role="menuitem">GLA 250 SUV</a>
# <a aria-label="Build, GLA 250 SUV" class="global-header__item-models-list-item-cta--build link" data-analytics-trigger="cta-build" href="/en/vehicles/build/gla/suv/gla250w" role="menuitem">Build</a>
# </li>
# <li class="global-header__item-models-list-item" role="none">
# <a class="global-header__item-models-list-item-cta--model link" data-analytics-trigger="cta" href="/en/vehicles/model/gla/suv/gla250w4" role="menuitem">GLA 250 4MATIC SUV</a>
# ...
#             title: "Registration was unsuccessful."
#         },
#         firstName: "First Name",
#         heading: "Not Registered? Create an account.",
#         hideEmailOptIn: false,
#         optinNameInSubscribeCallFlag: false,
#         invalidEmail: "Please enter a valid email address",
#         invalidLegalNotice: "Please review and accept policy",
#         lastName: "Last Name",
#         legalNoticeURI: "/en/legal-notices",
#         logIn: "log in",
#         loginHere: "Login here",
#         loginHereLC: "log in here",
#         pleaseEnterFirstName: "Please enter your first name",
#         pleaseEnterLastName: "Please enter your last name",
#         policies: "policies",
#         privacyPolicyAgreement: "I have read and agree to the Mercedes\u002DBenz {0}.",
#         recaptchaEmptyError: "Please confirm you are not a robot.",
#         recommendations: "Recommendations",
#         register: "Register",
#         registeredDescription: "By registering for a Mercedes me ID, you can access saved builds, inventory and more. Already have a Mercedes me ID? {0}",
#         reminderHeader: "Finish setting up your Mercedes me ID.",
#         reminderLogIn: "log in here",
#         reminderDescription: "Use the link in your confirmation email, sent to {0}. If you can’t find it, {1} and a new email will be sent with a secure verification code.",
#         savedBuilds: "Saved Builds",
#         savedInventory: "Saved Inventory",
#         serverError: {
#             description: "We were unable to process your request. Please try again.",
#             title: "We\x27re sorry, an error has occurred."
#         },
#         confirmationLogIn: "log in",
#         updates: "Yes, send me updates about my vehicles. (Optional)",
#         updatesHeader: "Would you like to stay informed about vehicles you\x27ve saved?",
#         validationError: "Please fix the information highlighted above",
#         endpoints: {
#             updateSubscriptionsURI: "/content/public-api/forms/preference/submit?api=updatesubscription"
#         }
#     };
#
#     // Localization for the saved vehicles panel
#     mbNafta.ns('pageData').savedVehiclesPanelLocalization = {
#         alreadyRegistered: "Already registered? {0}",
#         benefits: "Benefits include",
#         continue: "Continue",
#         createAccount: "Create an account",
#         logIn: "Log in",
#         loginHereLC: "log in here",
#         savedBuilds: "Saved Builds",
#         savedInventory: "Saved Inventory",
#         newBuildCta: "Start a New Build",
#         recommendations: "Recommendations",
#         unregisteredHeading: "Create an account to save builds and inventory.",
#         unregisteredSubheading: "With a Mercedes\u002DBenz account, you can save a build to see similar options nearby, or save inventory to monitor and compare. {0} to get started.",
#         unverifiedHeading: "Finish setting up your Mercedes me ID.",
#         unverifiedSubheading: "Use the link in your confirmation email, sent to {0}. If you can’t find it, {1} and a new email will be sent with a secure verification code.",
#         viewInventoryCta: "View Inventory"
#     };
#
#     // Localization for dealer selector
#     mbNafta.ns('pageData').dealerSelectorLocalization = {
#         changeLocation: "Change Location",
#         closestDealers: "These are the closest dealers based on your search.",
#         continueLabel: "Continue",
#         dealerSelectorFindTitle: "Find Local Inventory",
#         enterYourLocation: "Enter your location to view vehicles at a dealer near you.",
#         findDealer: "Find Dealer",
#         locationSearchErrorMessage: (mbNafta.pageData.country === 'us') ?  'Invalid ZIP Code or City, State' : "Invalid Postal Code or City, Province",
#         searchInputLabel: (mbNafta.pageData.country === 'us') ?  'ZIP Code or City, State' : "Postal Code or City, Province",
#         selectDealer: "Select the dealer whose inventory you\x27d like to see.",
#         theseAreDealersNear: "These are the dealers near {searchTerms}.",
#         viewAtDealer: "View Inventory at {dealerName}"
#     };
#
#     // Featured flags for dealer locator
#     mbNafta.ns('pageData', 'dealerLocatorPlugin', 'config').featureFlags = {
#         showSubheading: true,
#         showSearchContainer: true,
#         showChangeLocation: true,
#         showFilterBar: false,
#         showListHeading: false,
#         showDealerHours: false,
#         usePrimaryCTA: false,
#         showSecondaryCTA: false,
#         showDistance: false,
#         showBrowseState: false,
#         showLoadMore: false,
#         inlinePreferredDealer: true,
#         showPhoneNumbers: false,
#         showArrowIndicator: false,
#         showFullAddress: false
#     };
#
#     // Localization for dealer locator
#     mbNafta.ns('pageData', 'dealerLocatorPlugin').localization = {
#         moduleHeading: "Find Local Inventory",
#         searchInputLabel: "Enter ZIP Code or City, State",
#         searchCTA: "Find Dealer",
#         hideMapCTA: "Hide Map",
#         showMapCTA: "Show Map",
#         searchErrorMessage: "Invalid ZIP Code or City, State",
#         dealerResultCTA: "View Inventory",
#         suggestedDealer: "Suggested",
#         next: "Next",
#         previous: "Previous",
#         defaultSubheading: "Enter your location to view vehicles at a dealer near you.",
#         resultsSubheading: "Select the dealer whose inventory you\x27d like to see.",
#         subtext: "These are the dealers near {searchTerms}.",
#         changeLocationCTA: "Change Location",
#         preferredDealer: "Your Preferred Dealer",
#         noResultsFound: "No Results Found",
#         noResultsToView: "There are no dealerships to view. Try entering a different ZIP code.",
#         resetFilters: "Reset Your Filters",
#         serviceDownFirst: "We’re sorry, an error has occurred.",
#         serviceDownSecond: "We were unable to process your request. Please try again."
#     };
#
#     // Localization for Terms of Use - First Time Logged In User
#     mbNafta.ns('pageData', 'termsOfUse').localization = {
#         accept: "Accept and Continue",
#         decline: "Decline and Log Out",
#         description: "Accepting our Terms of Use will give you access to additional features throughout our site. Declining will log you out, but you will still be able to browse MBUSA.com.",
#         legalNoticeURI: "/en/legal-notices",
#         mercedesMePrivacyURI: "/en/legal-notices/privacy-statement",
#         mercedesMeServiceURI: "/en/legal-notices/mercedes-me-id",
#         ciamTermsURI: "/en/legal-notices/mercedes-me-id#login-requirements",
#         mercedesMePrivacy: "Mercedes me ID Privacy Policy",
#         mercedesMePrivacyLabel: "mercedes\u002Dme\u002Dprivacy\u002Dpolicy",
#         mercedesMeTerms: "Mercedes me ID Service Terms",
#         mercedesMeTermsLabel: "merceedes\u002Dme\u002Dterms",
#         policies: "policies",
#         privacyPolicy: "I acknowledge that I have read and agree to the Mercedes\u002DBenz policies, including the {0} and {1}.",
#         privacyPolicyLinkLabel: "Privacy Statement",
#         subtitle: "We’ve updated our Terms of Use since the last time you logged in.",
#         terms: "Terms of Use",
#         termsOfUseUri: "/en/legal-notices/terms-of-use",
#         title: "Legal Notice",
#         updateDescription: "Please accept these terms to continue to your account and enjoy all the features of MBUSA.com. If you decline, you will be logged out, but you can still browse the site.",
#     };
#
#     mbNafta.ns('pageData').globalDisclaimerLegends = {
#         MSRP: "*",
#         ACCELERATION: "**",
#         MPG: "†",
#         TOWING_CAPACITY: "‡",
#         HIGHWAY_ESTIMATE: "†",
#         CITY_FUEL_ECONOMY: "†"
#     };
# </script>
# <script>
#     mbNafta.loadApps(['main']);
# </script>
# <script>
#     mbNafta.ns('pageData', 'localization').changeDealer = "Change Dealer";
#     mbNafta.ns('pageData', 'localization').changeLocation = "Change Location";
#     mbNafta.ns('pageData', 'localization').goToNav = "Go To Navigation";
#     mbNafta.ns('pageData', 'localization').suggestedDealer = "Suggested";
#
#     mbNafta.ns('pageData', 'youtube').localization = {
#         alertYouTube: "Click here to watch video.",
#         hideVideoTranscript: "Hide Video Transcript",
#         modalAlertYouTube: "Click here to launch video in a pop\u002Dup.",
#         showVideoTranscript: "Show Video Transcript"
#     };
#
#     mbNafta.ns('pageData').dealerLocator = mbNafta.ns('pageData').dealerLocator || {};
#
#     mbNafta.ns('pageData', 'common')['config'] = {
#         optionImageFallback: "/content/dam/mb-nafta/us/byo/configurator/No-Image-Available.jpg"
#     };
#
#     window.disableLazyLoad = false;
# </script>
# <script>
#     mbNafta.loadApps(['analytics']);
#
#     mbDSDataLayer.ns('src').isProduction = true;
#     mbDSDataLayer.ns('src').type = "all\u002Dvehicles";
# </script>
# <script>
#     mbNafta.loadApps(['vehicles-all']);
#     mbNafta.ns('pageData').pageType = 'all';
# </script>
# <script>
#     mbNafta.webpackManifest = {"js/apps/accessories":{"js":["js/platform/webpack-runtime.js","js/vendors/06a54ff0ea5f07085398.bundle.js","js/vendors/dc47351ba0485112d12f.bundle.js","js/common/e567f1a543a37d80a359.bundle.js","js/apps/accessories.js"]},"js/apps/account-advanced-profile":{"js":["js/platform/webpack-runtime.js","js/vendors/06a54ff0ea5f07085398.bundle.js","js/vendors/dc47351ba0485112d12f.bundle.js","js/vendors/0f62a594518e0116be5e.bundle.js","js/vendors/3fdb3ef5010c887f9bd8.bundle.js","js/vendors/4672296e62071be86ac6.bundle.js","9936.js","js/vendors/67cb1e49ed50b8edba47.bundle.js","js/vendors/b57980a4299513815a97.bundle.js","js/vendors/6f777d71e209061f5fa3.bundle.js","js/vendors/cd9023fdc5b2c06a44ce.bundle.js","js/common/a375751c3638fb7644c6.bundle.js","js/common/af9622997be8935c051f.bundle.js","js/common/6217f4d753ec73827a22.bundle.js","js/common/a687df46909c6d70f6fd.bundle.js","js/common/85d95d2a0d0d91137a41.bundle.js","js/common/b99d61d602a7ce22590f.bundle.js","js/common/bd1bd82c8a9c17a01a1e.bundle.js","js/common/efec69604dd9207e95ed.bundle.js","js/common/f71ae93d4e55148021b3.bundle.js","js/common/b0aadfebf29ac94837e6.bundle.js","js/common/47bc083889e5c7866553.bundle.js","js/common/682624061caf8de842fa.bundle.js","js/common/c5974bfd2738a39a96af.bundle.js","js/common/f0a589aedec8d427e318.bundle.js","js/common/3285fb2a6af7087e3245.bundle.js","2405.js","544.js","6623.js","js/common/fd9ba5daecd1abb3bf0f.bundle.js","js/common/2c023d0fc2505b926989.bundle.js","js/common/f21dca5094e690343151.bundle.js","js/common/8ebcc18e42b41536c438.bundle.js","3269.js","js/common/8d874f6c3eb256011355.bundle.js","js/common/a2b4bd00445b3bd2102c.bundle.js","js/common/cba5a45b142b57ab6c32.bundle.js","js/common/9f8b0ec8c53766ba8b9a.bundle.js","js/common/b1ba9861223b8205ea84.bundle.js","js/apps/account-advanced-profile-5d00461c.js","js/apps/account-advanced-profile-9d2749cb.js"]},"js/apps/account-variant":{"js":["js/platform/webpack-runtime.js","js/vendors/06a54ff0ea5f07085398.bundle.js","js/vendors/dc47351ba0485112d12f.bundle.js","js/vendors/0f62a594518e0116be5e.bundle.js","js/vendors/3fdb3ef5010c887f9bd8.bundle.js","js/vendors/4672296e62071be86ac6.bundle.js","9936.js","js/vendors/67cb1e49ed50b8edba47.bundle.js","js/vendors/b57980a4299513815a97.bundle.js","js/vendors/6f777d71e209061f5fa3.bundle.js","js/vendors/cd9023fdc5b2c06a44ce.bundle.js","js/common/a375751c3638fb7644c6.bundle.js","js/common/af9622997be8935c051f.bundle.js","js/common/6217f4d753ec73827a22.bundle.js","js/common/a687df46909c6d70f6fd.bundle.js","js/common/b99d61d602a7ce22590f.bundle.js","js/common/bd1bd82c8a9c17a01a1e.bundle.js","js/common/efec69604dd9207e95ed.bundle.js","js/common/c5974bfd2738a39a96af.bundle.js","js/common/3285fb2a6af7087e3245.bundle.js","js/common/8ebcc18e42b41536c438.bundle.js","3269.js","js/common/8d874f6c3eb256011355.bundle.js","js/common/c69f46cb4aaf431fee0c.bundle.js","js/apps/account-variant.js"]},"js/apps/account":{"js":["js/platform/webpack-runtime.js","js/vendors/06a54ff0ea5f07085398.bundle.js","js/vendors/dc47351ba0485112d12f.bundle.js","js/vendors/0f62a594518e0116be5e.bundle.js","js/vendors/3fdb3ef5010c887f9bd8.bundle.js","js/vendors/4672296e62071be86ac6.bundle.js","9936.js","js/vendors/67cb1e49ed50b8edba47.bundle.js","js/vendors/b57980a4299513815a97.bundle.js","js/vendors/6f777d71e209061f5fa3.bundle.js","js/vendors/cd9023fdc5b2c06a44ce.bundle.js","js/common/a375751c3638fb7644c6.bundle.js","js/common/af9622997be8935c051f.bundle.js","js/common/6217f4d753ec73827a22.bundle.js","js/common/a687df46909c6d70f6fd.bundle.js","js/common/b99d61d602a7ce22590f.bundle.js","js/common/bd1bd82c8a9c17a01a1e.bundle.js","js/common/efec69604dd9207e95ed.bundle.js","js/common/c5974bfd2738a39a96af.bundle.js","js/common/3285fb2a6af7087e3245.bundle.js","js/common/8ebcc18e42b41536c438.bundle.js","3269.js","js/common/8d874f6c3eb256011355.bundle.js","js/common/cba5a45b142b57ab6c32.bundle.js","js/common/c69f46cb4aaf431fee0c.bundle.js","js/apps/account.js"]},"js/apps/analyti ...
# </script>
# <!-- Generated manually from mbusa-application-loader.js -->
# <script>
# !function(){var t="/etc/designs/mb-nafta";function p(e,a,n,t,f){e===a&&"function"==typeof t?t():e===a&&n&&"function"==typeof f&&f()}mbNafta.webpackManifest=mbNafta.webpackManifest||null,mbNafta.jsDepenencies=[],mbNafta.loadDependencyManifest=function(e){if(mbNafta.webpackManifest&&"function"==typeof e)e();else if(!mbNafta.webpackManifest)try{var a=new XMLHttpRequest;a.overrideMimeType("application/json"),a.open("GET","/etc/designs/mb-nafta/webpack-manifest.json",!0),a.onreadystatechange=function(){4===a.readyState&&"200"===a.status.toString()&&(mbNafta.webpackManifest=JSON.parse(a.responseText),"function"==typeof e&&e())},a.send(null)}catch(e){console.error("Error parsing JSON manifest",e)}},mbNafta.loadDependency=function(e,a){var n=document.querySelector("head"),t=document.createElement("script");t.src=e,t.defer=!0,t.onload=function(){a(!0)},t.onerror=function(){a(!1)},n.appendChild(t)},mbNafta.loadDependencyAssets=function(n,t,f,s,i){var c=0,o=!1;n&&n.forEach(function(e){if(mbNafta.jsDepenencies.includes(e))p(++c,n.length,t,f);else{var a=s?s+"/"+e:e;mbNafta.jsDepenencies.push(e),mbNafta.loadDependency(a,function(e){e||(o=!0),p(++c,n.length,o,t,f)},i)}})},mbNafta.loadDependencies=function(i,e,a,n){mbNafta.loadDependencyManifest(function(){if(Array.isArray(e)){var s=[];e.forEach(function(e){var a,n,t=(n=e,"plugins"===(a=i)?a+"/"+n+"/js/"+n:"js/"+a+"/"+n),f=mbNafta.webpackManifest[t]&&mbNafta.webpackManifest[t].js;f&&(s=s.concat(f))}),mbNafta.loadDependencyAssets(s,a,n,t)}})},mbNafta.loadDependencyManifest(function(){mbNafta.externalLibraries&&0<mbNafta.externalLibraries.length?mbNafta.loadDependencyAssets(mbNafta.externalLibraries,function(){mbNafta.loadDependencies("apps",mbNafta.apps),mbNafta.loadDependencies("plugins",mbNafta.plugins)},function(){console.warn("loadLibraryDependencies: error")}):(mbNafta.loadDependencies("apps",mbNafta.apps),mbNafta.loadDependencies("plugins",mbNafta.plugins))})}();
# </script>
# <!-- Generated manually from mbusa-web-id.js -->
# <script>
#   !function(){function n(t){for(var n=t+"=",e=document.cookie.split(";"),o=0;o<e.length;o++){for(var r=e[o];" "==r.charAt(0);)r=r.substring(1);if(0===r.indexOf(n))return r.substring(n.length,r.length)}return""}function e(){return"xxxxxxxx-xxxx-4xxx-yxxx-xxxxxxxxxxxx".replace(/[xy]/g,function(t){var n=16*Math.random()|0;return("x"==t?n:3&n|8).toString(16)})}function o(){return!(!n("MBUSA_WEB_ID")||!n("MBUSA_WEB_ID").length)}mbNafta.ns("utils").getCookie=n,mbNafta.ns("utils").uuidv4=e,mbNafta.ns("utils").checkMBUSAWEBID=o,function(){var t={};if(window.localStorage&&window.localStorage.getItem("MBUSA_WEB_ID"))try{t=JSON.parse(window.localStorage.getItem("MBUSA_WEB_ID"))}catch(t){console.error(t)}t.id?t.lastSaved=(new Date).toUTCString():t={id:o()?n("MBUSA_WEB_ID"):e(),lastSaved:(new Date).toUTCString()};try{window.localStorage.setItem("MBUSA_WEB_ID",JSON.stringify(t))}catch(t){console.error(t)}document.cookie="MBUSA_WEB_ID="+t.id+"; Path=/; SameSite=None; Secure; Max-Age=31536000"}(),window._dtm={ciam_id:n("mbusa_hashed")}}();
# </script>
# </body>
# </html>

# %% [markdown]
# ## Results

# %%
results = soup.find_all('div', {'class':'all-vehicles__class module-separator'})

# %%
results[0]
# Out:
# <div class="all-vehicles__class module-separator" data-analytics-container="{'class': 'GLA', 'bodystyle': 'SUV'}">
# <a data-analytics-trigger="cta" href="/en/vehicles/class/gla/suv"><h3 class="all-vehicles__class-name">GLA SUV</h3></a>
# <h4 class="all-vehicles__class-price">
#                     Starting at
#                     <span>
#                         $36,400
#
#
#
#
#
#
#
#
#
#
#
#         <a aria-controls="disclaimer-drawer" class="disclaimer__marker" data-legend="*" href="#disclaimer-drawer">
# <span class="offscreen">Disclaimer</span>*
#
#         </a>
# </span>
# </h4>
# <p class="all-vehicles__class-tagline">
#                     Compact &amp; Sleek
#                 </p>
# <a aria-label="GLA SUV" class="all-vehicles__class-page-link" data-analytics-trigger="cta" href="/en/vehicles/class/gla/suv">
# <img alt="" class="all-vehicles__class-image" src="/content/dam/mb-nafta/us/myco/my22/gla/all-vehicles/2022-GLA-SUV-AVP-DR.png"/>
# </a>
# <div class="all-vehicles__class-more-info">
# <button aria-controls="vbg-suvs--model-list-1" aria-expanded="false" aria-label="View Models, GLA SUV" class="all-vehicles__class-models-cta" data-analytics-trigger="cta" href="#">View Models</button>
# <ul aria-hidden="true" class="all-vehicles__models-list" id="vbg-suvs--model-list-1">
# <li class="all-vehicles__model">
# <a class="all-vehicles__model-name link link_plain-link" data-analytics-container="{'model': 'GLA250W'}" data-analytics-trigger="cta-model" href="/en/vehicles/model/gla/suv/gla250w">
# <span>
#                                             GLA 250 SUV
#
#                                         </span>
# <span class="all-vehicles__model-price">$36,400*</span>
# </a>
# </li>
# <li class="all-vehicles__model">
# <a class="all-vehicles__model-name link link_plain-link" data-analytics-container="{'model': 'GLA250W4'}" data-analytics-trigger="cta-model" href="/en/vehicles/model/gla/suv/gla250w4">
# <span>
#                                             GLA 250 4MATIC SUV
#
#                                         </span>
# <span class="all-vehicles__model-price">$38,400*</span>
# </a>
# </li>
# <li class="all-vehicles__model">
# <a class="all-vehicles__model-name link link_plain-link" data-analytics-container="{'model': 'GLA35W4'}" data-analytics-trigger="cta-model" href="/en/vehicles/model/gla/suv/gla35w4">
# <span>
#                                             AMG GLA 35 SUV
#
#                                         </span>
# <span class="all-vehicles__model-price">$47,950*</span>
# </a>
# </li>
# <li class="all-vehicles__model">
# <a class="all-vehicles__model-name link link_plain-link" data-analytics-container="{'model': 'GLA45W4'}" data-analytics-trigger="cta-model" href="/en/vehicles/model/gla/suv/gla45w4">
# <span>
#                                             AMG GLA 45 SUV
#
#                                         </span>
# <span class="all-vehicles__model-price">$55,400*</span>
# </a>
# </li>
# </ul>
# <a aria-label="Build GLA SUV" class="all-vehicles__class-build-cta link" data-analytics-trigger="build" href="/en/vehicles/build/gla/suv">Build</a>
# </div>
# </div>

# %%
len(results)
# Out:
# 27

# %% [markdown]
# ## Specify Necessary Target Data

# %%
# Name
# Starting Price
# Tagline
# Models and Price

# %% [markdown]
# ## Name

# %%
results[0].find('h3').get_text()
# Out:
# 'GLA SUV'

# %% [markdown]
# ## Starting Price

# %%
results[0].find('span').get_text(strip=True).replace("Disclaimer*", "")
# Out:
# '$36,400'

# %% [markdown]
# ## Tagline

# %%
results[1].find('p', {'class':'all-vehicles__class-tagline'}).get_text(strip=True)
# Out:
# 'Adventurous'

# %% [markdown]
# ## Models and Price

# %%
results[0].find('ul', {'class':'all-vehicles__models-list'}).get_text(strip=True).replace("$", " - $").replace(",", "").replace("*", "\r\n")
# Out:
# 'GLA 250 SUV - $36400\r\nGLA 250 4MATIC SUV - $38400\r\nAMG GLA 35 SUV - $47950\r\nAMG GLA 45 SUV - $55400\r\n'

# %% [markdown]
# # Combining Everything Together using For Loop

# %%
name = []
starting_price = []
tagline = []
models_and_price = []

for result in results:
    
        # name
        try:
            name.append(result.find('h3').get_text())
        except:
            name.append('n/a')
            
         # starting price
        try:
            starting_price.append(result.find('span').get_text(strip=True).replace("Disclaimer*", ""))
        except:
            starting_price.append('n/a')
            
        # tagline
        try:
            tagline.append(result.find('p', {'class':'all-vehicles__class-tagline'}).get_text(strip=True))
        except:
            tagline.append('n/a')
            
        # models_and_price
        try:
            models_and_price.append(result.find('ul', {'class':'all-vehicles__models-list'}).get_text(strip=True).replace("$", " - $").replace(",", "").replace("*", ", "))
        except:
            models_and_price.append('n/a')

# %%
models_and_price
# Out:
# ['GLA 250 SUV - $36400, GLA 250 4MATIC SUV - $38400, AMG GLA 35 SUV - $47950, AMG GLA 45 SUV - $55400, ',
#  'GLB 250 SUV - $38600, GLB 250 4MATIC SUV - $40600, AMG GLB 35 SUV - $49950, ',
#  'GLC 300 SUV - $43850, GLC 300 4MATIC SUV - $45850, AMG GLC 43 SUV - $59900, ',
#  'GLC 300 4MATIC Coupe - $52500, AMG GLC 43 Coupe - $66500, ',
#  'GLE 350 SUV - $56150, GLE 350 4MATIC SUV - $58650, GLE 450 4MATIC SUV - $63950, AMG GLE 53 4MATIC+ SUV - $74150, ',
#  'AMG GLE 53 Coupe - $78450, ',
#  'GLS 450 SUV - $77850, ',
#  'Mercedes-Maybach GLS 600 SUV - $160500, ',
#  'G 550 SUV - $131750, AMG G 63 SUV - $156450, ',
#  'A 220 Sedan - $33950, A 220 4MATIC Sedan - $35950, ',
#  'C 300 SedanPrice Coming SoonC 300 4MATIC SedanPrice Coming Soon',
#  'E 350 Sedan - $54950, E 350 4MATIC Sedan - $57450, E 450 4MATIC Sedan - $62750, AMG E 53 Sedan - $75000, ',
#  'EQS 450+ Sedan - $102310, EQS 580 4MATIC Sedan - $125900, ',
#  'S 500 4MATIC Sedan - $111100, S 580 4MATIC Sedan - $117700, ',
#  'Mercedes-Maybach S 580 4MATIC - $184900, Mercedes-Maybach S 680 4MATICPrice Coming Soon',
#  'E 450 4MATIC All-Terrain Wagon - $68400, ',
#  'CLA 250 Coupe - $38200, CLA 250 4MATIC Coupe - $40200, AMG CLA 35 Coupe - $47900, AMG CLA 45 Coupe - $55900, ',
#  'C 300 Coupe - $47850, C 300 4MATIC Coupe - $49850, AMG C 43 Coupe - $60500, ',
#  'E 450 Coupe - $66100, E 450 4MATIC Coupe - $68600, AMG E 53 Coupe - $77600, ',
#  'CLS 450 4MATIC Coupe - $72950, ',
#  'AMG GT 43 4-door Coupe - $92500, AMG GT 53 4-door Coupe - $102600, ',
#  'AMG GT Coupe - $118600, AMG GT C Coupe - $153500, AMG GT Black Series Coupe - $325000, ',
#  'C 300 Cabriolet - $55400, C 300 4MATIC Cabriolet - $57400, AMG C 43 Cabriolet - $67000, ',
#  'E 450 Cabriolet - $73250, E 450 4MATIC Cabriolet - $75750, AMG E 53 Cabriolet - $84350, ',
#  'AMG GT Roadster - $130700, AMG GT C Roadster - $165100, ',
#  'AMG SL 55 RoadsterPrice Coming SoonAMG SL 63 RoadsterPrice Coming Soon',
#  'EQS 450+ Sedan - $102310, EQS 580 4MATIC Sedan - $125900, ']

# %% [markdown]
# ## Rename Dataframe

# %%
df = pd.DataFrame({'Name': name, 'Starting Price':starting_price, 'Tagline':tagline,
                                'Model and Price': models_and_price})
df
# Out:
#                             Name                       Starting Price  \
# 0                        GLA SUV                              $36,400
# 1                        GLB SUV                              $38,600
# 2                        GLC SUV                              $43,850
# 3                      GLC Coupe                              $52,500
# 4                        GLE SUV                              $56,150
# 5                      GLE Coupe                              $78,450
# 6                        GLS SUV                              $77,850
# 7       Mercedes-Maybach GLS SUV                             $160,500
# 8                    G-Class SUV                             $131,750
# 9                  A-Class Sedan                              $33,950
# 10                 C-Class Sedan                          C 300 Sedan
# 11                 E-Class Sedan                              $54,950
# 12                     EQS Sedan                             $102,310
# 13                 S-Class Sedan                             $111,100
# 14      Mercedes-Maybach S-Class                             $184,900
# 15                 E-Class Wagon                              $68,400
# 16                     CLA Coupe                              $38,200
# 17                 C-Class Coupe                              $47,850
# 18                 E-Class Coupe                              $66,100
# 19                     CLS Coupe                              $72,950
# 20  Mercedes-AMG GT 4-door Coupe                              $92,500
# 21               Mercedes-AMG GT                             $118,600
# 22             C-Class Cabriolet                              $55,400
# 23             E-Class Cabriolet                              $73,250
# 24               Mercedes-AMG GT                             $130,700
# 25                   SL Roadster  AMG SL 55 RoadsterPrice Coming Soon
# 26                     EQS Sedan                             $102,310
#
#                       Tagline  \
# 0             Compact & Sleek
# 1                 Adventurous
# 2             Mid-Size & Chic
# 3           Sporty & Spacious
# 4                Well-Rounded
# 5            High-Performance
# 6            Full-Size Luxury
# 7   The new height of luxury.
# 8               Off-Road Icon
# 9                    Advanced
# 10            Stylish & Agile
# 11          Ultra-Intelligent
# 12                Progressive
# 13            Luxury Standard
# 14               Unparalleled
# 15                  Versatile
# 16                  Seductive
# 17              Bold & Sporty
# 18            Smart & Stylish
# 19                   Powerful
# 20            Fast & Spacious
# 21          Elite Performance
# 22                     Nimble
# 23                   Spacious
# 24              Awe-Inspiring
# 25                  Legendary
# 26                Progressive
#
#                                       Model and Price
# 0   GLA 250 SUV - $36400, GLA 250 4MATIC SUV - $38...
# 1   GLB 250 SUV - $38600, GLB 250 4MATIC SUV - $40...
# 2   GLC 300 SUV - $43850, GLC 300 4MATIC SUV - $45...
# 3   GLC 300 4MATIC Coupe - $52500, AMG GLC 43 Coup...
# 4   GLE 350 SUV - $56150, GLE 350 4MATIC SUV - $58...
# 5                         AMG GLE 53 Coupe - $78450,
# 6                              GLS 450 SUV - $77850,
# 7            Mercedes-Maybach GLS 600 SUV - $160500,
# 8       G 550 SUV - $131750, AMG G 63 SUV - $156450,
# 9   A 220 Sedan - $33950, A 220 4MATIC Sedan - $35...
# 10  C 300 SedanPrice Coming SoonC 300 4MATIC Sedan...
# 11  E 350 Sedan - $54950, E 350 4MATIC Sedan - $57...
# 12  EQS 450+ Sedan - $102310, EQS 580 4MATIC Sedan...
# 13  S 500 4MATIC Sedan - $111100, S 580 4MATIC Sed...
# 14  Mercedes-Maybach S 580 4MATIC - $184900, Merce...
# 15          E 450 4MATIC All-Terrain Wagon - $68400,
# 16  CLA 250 Coupe - $38200, CLA 250 4MATIC Coupe -...
# 17  C 300 Coupe - $47850, C 300 4MATIC Coupe - $49...
# 18  E 450 Coupe - $66100, E 450 4MATIC Coupe - $68...
# 19                    CLS 450 4MATIC Coupe - $72950,
# 20  AMG GT 43 4-door Coupe - $92500, AMG GT 53 4-d...
# 21  AMG GT Coupe - $118600, AMG GT C Coupe - $1535...
# 22  C 300 Cabriolet - $55400, C 300 4MATIC Cabriol...
# 23  E 450 Cabriolet - $73250, E 450 4MATIC Cabriol...
# 24  AMG GT Roadster - $130700, AMG GT C Roadster -...
# 25  AMG SL 55 RoadsterPrice Coming SoonAMG SL 63 R...
# 26  EQS 450+ Sedan - $102310, EQS 580 4MATIC Sedan...

# %% [markdown]
# ## Split Row into Different Model with Their Corresponding Price

# %%
df= (df.set_index(['Name', 'Starting Price', 'Tagline'])
   .apply(lambda x: x.str.split(',').explode())
   .reset_index())                                                   
df
# Out:
#                Name                       Starting Price          Tagline  \
# 0           GLA SUV                              $36,400  Compact & Sleek
# 1           GLA SUV                              $36,400  Compact & Sleek
# 2           GLA SUV                              $36,400  Compact & Sleek
# 3           GLA SUV                              $36,400  Compact & Sleek
# 4           GLA SUV                              $36,400  Compact & Sleek
# ..              ...                                  ...              ...
# 81  Mercedes-AMG GT                             $130,700    Awe-Inspiring
# 82      SL Roadster  AMG SL 55 RoadsterPrice Coming Soon        Legendary
# 83        EQS Sedan                             $102,310      Progressive
# 84        EQS Sedan                             $102,310      Progressive
# 85        EQS Sedan                             $102,310      Progressive
#
#                                       Model and Price
# 0                                GLA 250 SUV - $36400
# 1                         GLA 250 4MATIC SUV - $38400
# 2                             AMG GLA 35 SUV - $47950
# 3                             AMG GLA 45 SUV - $55400
# 4
# ..                                                ...
# 81
# 82  AMG SL 55 RoadsterPrice Coming SoonAMG SL 63 R...
# 83                           EQS 450+ Sedan - $102310
# 84                     EQS 580 4MATIC Sedan - $125900
# 85
#
# [86 rows x 4 columns]

# %% [markdown]
# ## Export Output in Excel

# %%
df.to_excel('Mercedes Database.xlsx', index=False)
